# %%
import tensorflow as tf
import numpy as np
import pickle
import os

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense
from tensorflow.keras.utils import to_categorical

# Load Shakespeare dataset
filepath = tf.keras.utils.get_file(
    "shakespeare.txt",
    "https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt"
)

with open(filepath, "r", encoding="utf-8") as f:
    text = f.read().lower()

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])

total_words = len(tokenizer.word_index) + 1

# Create sequences
input_sequences = []

for line in text.split("\n"):

    token_list = tokenizer.texts_to_sequences([line])[0]

    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i + 1]
        input_sequences.append(n_gram_sequence)

max_sequence_len = max(
    len(sequence)
    for sequence in input_sequences
)

input_sequences = np.array(
    pad_sequences(
        input_sequences,
        maxlen=max_sequence_len,
        padding="pre"
    )
)

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

y = to_categorical(
    y,
    num_classes=total_words
)

# GRU Model
model = Sequential([
    Embedding(
        total_words,
        100,
        input_length=max_sequence_len - 1
    ),

    GRU(
        150
    ),

    Dense(
        total_words,
        activation="softmax"
    )
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

model.fit(
    X,
    y,
    epochs=10,
    batch_size=128
)

# Save model
os.makedirs("../models", exist_ok=True)

model.save(
    "../models/gru_shakespeare.keras"
)

with open("../models/tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)

with open("../models/max_sequence_len.pkl", "wb") as f:
    pickle.dump(max_sequence_len, f)

print("Model saved successfully")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\vamsh\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:103: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 85
#      77 model.compile(
#      78     optimizer="adam",
#      79     loss="categorical_crossentropy",
#      80     metrics=["accuracy"]
#      81 )
#      83 model.summary()
# ---> 85 model.fit(
#      86     X,
#      87     y,
#      88     epochs=10,
#      89     batch_size=128
#      90 )
#      92 # Save model
#      93 os.makedirs("../models", exist_ok=True)
#
# File c:\Users\vamsh\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\vamsh\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:360, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     353     (
#     354         val_x,
#     355         val_y,
#     356         val_sample_weight,
#     357     ) = data_adapter_utils.unpack_x_y_sample_weight(validation_data)
#     359 # Create an iterator that yields batches for one epoch.
# --> 360 epoch_iterator = TFEpochIterator(
#     361     x=x,
#     362     y=y,
#     363     sample_weight=sample_weight,
#     364     batch_size=batch_size,
#     365     steps_per_epoch=steps_per_epoch,
#     366     shuffle=shuffle,
#     367     class_weight=class_weight,
#     368     distribute_strategy=self.distribute_strategy,
#     369     steps_per_execution=self.steps_per_execution,
#     370 )
#     372 self._maybe_symbolic_build(iterator=epoch_iterator)
#     373 epoch_iterator.reset()
#
# File c:\Users\vamsh\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:750, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     748 super().__init__(*args, **kwargs)
#     749 self._distribute_strategy = distribute_strategy
# --> 750 dataset = self.data_adapter.get_tf_dataset()
#     751 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     752     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     753         dataset
#     754     )
#
# File c:\Users\vamsh\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:237, in ArrayDataAdapter.get_tf_dataset(self)
#     234 if shuffle == "batch":
#     235     indices_dataset = indices_dataset.map(tf.random.shuffle)
# --> 237 dataset = slice_inputs(indices_dataset, self._inputs)
#     239 options = tf.data.Options()
#     240 options.experimental_distribute.auto_shard_policy = (
#     241     tf.data.experimental.AutoShardPolicy.DATA
#     242 )
#
# File c:\Users\vamsh\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:193, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_inputs(indices_dataset, inputs)
#     178 def slice_inputs(indices_dataset, inputs):
#     179     """Slice inputs into a Dataset of batches.
#     180
#     181     Given a Dataset of batch indices and the unsliced inputs,
#    (...)
#     191         A Dataset of input batches matching the batch indices.
#     192     """
# --> 193     inputs = array_slicing.convert_to_sliceable(
#     194         self._inputs, target_backend="tensorflow"
#     195     )
#     196     inputs = tree.lists_to_tuples(inputs)
#     198     dataset = tf.data.Dataset.zip(
#     199         (indices_dataset, tf.data.Dataset.from_tensors(inputs).repeat())
#     200     )
#
# File c:\Users\vamsh\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_slicing.py:458, in convert_to_sliceable(arrays, target_backend)
#     454         sliceable_class = NumpySliceable
#     456     return sliceable_class(x)
# --> 458 return tree.map_structure(convert_single_array, arrays)
#
# File c:\Users\vamsh\anaconda3\Lib\site-packages\keras\src\tree\tree_api.py:200, in map_structure(func, none_is_leaf, *structures)
#     167 @keras_export("keras.tree.map_structure")
#     168 def map_structure(func, *structures, none_is_leaf=True):
#     169     """Maps `func` through given structures.
#     170
#     171     Examples:
#    (...)
#     198             `assert_same_structure`.
#     199     """
# --> 200     return tree_impl.map_structure(func, *structures, none_is_leaf=none_is_leaf)
#
# File c:\Users\vamsh\anaconda3\Lib\site-packages\keras\src\tree\optree_impl.py:111, in map_structure(func, none_is_leaf, *structures)
#     107     return func(*args)
#     109 map_func = func_with_check if len(structures) > 1 else func
# --> 111 return optree.tree_map(
#     112     map_func, *structures, none_is_leaf=none_is_leaf, namespace="keras"
#     113 )
#
# File c:\Users\vamsh\anaconda3\Lib\site-packages\optree\ops.py:782, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     780 leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#     781 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 782 return treespec.unflatten(map(func, *flat_args))
#
# File c:\Users\vamsh\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_slicing.py:435, in convert_to_sliceable.<locals>.convert_single_array(x)
#     432         cast_dtype = backend.floatx()
#     434 if cast_dtype is not None:
# --> 435     x = sliceable_class.cast(x, cast_dtype)
#     437 # Step 3. Apply target backend specific logic and optimizations.
#     438 if target_backend is None:
#
# File c:\Users\vamsh\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_slicing.py:63, in Sliceable.cast(cls, x, dtype)
#      53 @classmethod
#      54 def cast(cls, x, dtype):
#      55     """Cast a tensor to a different dtype.
#      56
#      57     Only called on a full array as provided by the user.
#    (...)
#      61     Returns: the cast tensor.
#      62     """
# ---> 63     return x.astype(dtype)
#
# KeyboardInterrupt:
